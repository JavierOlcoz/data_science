# %% [markdown]
# ### Bonus Track.
# This Bonus Track could take you some days, it is very ok, sometimes coding is all about time.
#
# This week, you'll also learn about .py files and you will be able to implement this program into that kind of file. Not yet, tho.
#
#
#
#
#
#
# Program a calculator that asks for two numbers and two operators on the screen. One operation must be performed first and then another. Try to define as many functions as possible.

# %%
"""
He intentado hacer todas las operaciones que se me ocurrían con dos números sin que tuviese que recurrir a la librería .math o que involucrasen un proceso matemático(como el mínimo común múltiplo) en lugar de una operación directa
"""

# Primero pido los números y las operaciones a realizar

a = float(input(print("Introduzca el primer número")))
print("Su primer número es:", a)

b = float(input(print("Introduzca el segundo número")))
print("Su segundo número es:", b)

c = input(print("Seleccione la primera operación entre: suma, resta, producto, division, resto, potencia, raiz, comparacion, division_absoluta"))
print("Ha seleccionado:", c)

d = input(print("Seleccione la primera operación entre: suma, resta, producto, division, resto, potencia, raiz, comparacion, division_absoluta"))
print("Ha seleccionado:", d)

# Defino las funciones que podrá hacer nuestra calcualdora

def suma(x,y):
    """Suma elementos
    """
    z = x + y
    print("La suma es:", z)
    return z

def resta(x,y):
    """Resta elementos
    """
    z = x - y # Bastante inútil esta función dado que la resta no deja de ser una suma de un número negativo a otro
    print("La resta es:",z)
    return z

def producto(x,y):
    """Multiplica los elementos
    """
    z = x * y
    print("El producto es:", z)
    return z

def division(x,y):
    """Divide elementos
    """
    z = x / y
    print("La división da:", z)
    return z

def resto(x,y):
    """Devuelve el resto de dividir x / y
    """
    z = x % y
    print("El resto es:", z)
    return z

def potencia(x,y):
    """Eleva el primer elemento al segundo
    """
    z = x ** y
    print("La potencia da:", z)
    return z

def raiz(x,y):
    """ Calcula la raíz siendo x el radicando e y el índice radical
    """
    z = x ** (1/y)
    print("La raíz es:", z)
    return z

def comparacion(x,y):
    """Compara elementos
    """
    if x < y:
        return print(y, "es mayor que", x)
    else:
        return print(x, "es mayor que", y)

def division_absoluta(x,y):
    """Hace la división absoluta
    """
    z = x // y
    print("La división absoluta da:", z)
    return z

# Sentencio que función se realizará en cada caso

if c == "suma":
    suma(x=a,y=b)

    if d == "suma":
        suma(x=a,y=b)
    elif d == "resta":
        resta(x=a,y=b)

    elif d == "producto":
        producto(x=a,y=b)

    elif d == "division":
        division(x=a,y=b)

    elif d == "resto":
        resto(x=a,y=b)

    elif d == "potencia":
        potencia(x=a,y=b)

    elif d == "raiz":
        raiz(x=a,y=b)

    elif d == "comparacion":
        comparacion(x=a,y=b)

    elif d == "division absoluta":
        division_absoluta(x=a,y=b)

    else: 
        print("La operación", d, "no está entre las ofertadas por este calculador, try again :)")

elif c == "resta":
    resta(x=a,y=b)

    if d == "suma":
        suma(x=a,y=b)
    elif d == "resta":
        resta(x=a,y=b)

    elif d == "producto":
        producto(x=a,y=b)

    elif d == "division":
        division(x=a,y=b)

    elif d == "resto":
        resto(x=a,y=b)

    elif d == "potencia":
        potencia(x=a,y=b)

    elif d == "raiz":
        raiz(x=a,y=b)

    elif d == "comparacion":
        comparacion(x=a,y=b)

    elif d == "division absoluta":
        division_absoluta(x=a,y=b)

    else: 
        print("La operación", d, "no está entre las ofertadas por este calculador, try again :)")

elif c == "producto":
    producto(x=a,y=b)

    if d == "suma":
        suma(x=a,y=b)
    elif d == "resta":
        resta(x=a,y=b)

    elif d == "producto":
        producto(x=a,y=b)

    elif d == "division":
        division(x=a,y=b)

    elif d == "resto":
        resto(x=a,y=b)

    elif d == "potencia":
        potencia(x=a,y=b)

    elif d == "raiz":
        raiz(x=a,y=b)

    elif d == "comparacion":
        comparacion(x=a,y=b)

    elif d == "division absoluta":
        division_absoluta(x=a,y=b)

    else: 
        print("La operación", d, "no está entre las ofertadas por este calculador, try again :)")

elif c == "division":
    division(x=a,y=b)

    if d == "suma":
        suma(x=a,y=b)
    elif d == "resta":
        resta(x=a,y=b)

    elif d == "producto":
        producto(x=a,y=b)

    elif d == "division":
        division(x=a,y=b)

    elif d == "resto":
        resto(x=a,y=b)

    elif d == "potencia":
        potencia(x=a,y=b)

    elif d == "raiz":
        raiz(x=a,y=b)

    elif d == "comparacion":
        comparacion(x=a,y=b)

    elif d == "division absoluta":
        division_absoluta(x=a,y=b)

    else: 
        print("La operación", d, "no está entre las ofertadas por este calculador, try again :)")

elif c == "resto":
    resto(x=a,y=b)

    if d == "suma":
        suma(x=a,y=b)
    elif d == "resta":
        resta(x=a,y=b)

    elif d == "producto":
        producto(x=a,y=b)

    elif d == "division":
        division(x=a,y=b)

    elif d == "resto":
        resto(x=a,y=b)

    elif d == "potencia":
        potencia(x=a,y=b)

    elif d == "raiz":
        raiz(x=a,y=b)

    elif d == "comparacion":
        comparacion(x=a,y=b)

    elif d == "division absoluta":
        division_absoluta(x=a,y=b)

    else: 
        print("La operación", d, "no está entre las ofertadas por este calculador, try again :)")

elif c == "potencia":
    potencia(x=a,y=b)

    if d == "suma":
        suma(x=a,y=b)
    elif d == "resta":
        resta(x=a,y=b)

    elif d == "producto":
        producto(x=a,y=b)

    elif d == "division":
        division(x=a,y=b)

    elif d == "resto":
        resto(x=a,y=b)

    elif d == "potencia":
        potencia(x=a,y=b)

    elif d == "raiz":
        raiz(x=a,y=b)

    elif d == "comparacion":
        comparacion(x=a,y=b)

    elif d == "division absoluta":
        division_absoluta(x=a,y=b)

    else: 
        print("La operación", d, "no está entre las ofertadas por este calculador, try again :)")

elif c == "raiz":
    raiz(x=a,y=b)

    if d == "suma":
        suma(x=a,y=b)
    elif d == "resta":
        resta(x=a,y=b)

    elif d == "producto":
        producto(x=a,y=b)

    elif d == "division":
        division(x=a,y=b)

    elif d == "resto":
        resto(x=a,y=b)

    elif d == "potencia":
        potencia(x=a,y=b)

    elif d == "raiz":
        raiz(x=a,y=b)

    elif d == "comparacion":
        comparacion(x=a,y=b)

    elif d == "division absoluta":
        division_absoluta(x=a,y=b)

    else:
        print("La operación", d, "no está entre las ofertadas por este calculador, try again :)")

elif c == "comparacion":
    comparacion(x=a,y=b)

    if d == "suma":
        suma(x=a,y=b)
    elif d == "resta":
        resta(x=a,y=b)

    elif d == "producto":
        producto(x=a,y=b)

    elif d == "division":
        division(x=a,y=b)

    elif d == "resto":
        resto(x=a,y=b)

    elif d == "potencia":
        potencia(x=a,y=b)

    elif d == "raiz":
        raiz(x=a,y=b)

    elif d == "comparacion":
        comparacion(x=a,y=b)

    elif d == "division absoluta":
        division_absoluta(x=a,y=b)

    else: 
        print("La operación", d, "no está entre las ofertadas por este calculador, try again :)")

elif c == "division absoluta":
    division_absoluta(x=a,y=b)

    if d == "suma":
        suma(x=a,y=b)
    elif d == "resta":
        resta(x=a,y=b)

    elif d == "producto":
        producto(x=a,y=b)

    elif d == "division":
        division(x=a,y=b)

    elif d == "resto":
        resto(x=a,y=b)

    elif d == "potencia":
        potencia(x=a,y=b)

    elif d == "raiz":
        raiz(x=a,y=b)

    elif d == "comparacion":
        comparacion(x=a,y=b)

    elif d == "division absoluta":
        division_absoluta(x=a,y=b)
    
    else: 
        print("La operación", d, "no está entre las ofertadas por este calculador, try again :)")

else: 
    print("La operación",c, "no está entre las ofertadas por este calculador, try again :)")

    if d == "suma":
        suma(x=a,y=b)
    elif d == "resta":
        resta(x=a,y=b)

    elif d == "producto":
        producto(x=a,y=b)

    elif d == "division":
        division(x=a,y=b)

    elif d == "resto":
        resto(x=a,y=b)

    elif d == "potencia":
        potencia(x=a,y=b)

    elif d == "raiz":
        raiz(x=a,y=b)

    elif d == "comparacion":
        comparacion(x=a,y=b)

    elif d == "division absoluta":
        division_absoluta(x=a,y=b)
    
    else: 
        print("La operación", d, "no está entre las ofertadas por este calculador, try again :)")
# Out:
# Introduzca el primer número
# Su primer número es: 5.0
# Introduzca el segundo número
# Su segundo número es: 6.0
# Seleccione la primera operación entre: suma, resta, producto, division, resto, potencia, raiz, comparacion, division_absoluta
# Ha seleccionado: k
# Seleccione la primera operación entre: suma, resta, producto, division, resto, potencia, raiz, comparacion, division_absoluta
# Ha seleccionado: k
# La operación k no está entre las ofertadas por este calculador, try again :)
# La  operación k no está entre las ofertadas por este calculador, try again :)
